# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

Europe_GDP= pd.read_csv("Europe_GDP.csv").convert_dtypes()

# %%
Europe_GDP.head()
# Out:
#    Year       Austria        Belgium       Denmark       Finland  \
# 0  1960  6650133915.0  11810619368.0  6361166313.0  5279011362.0
# 1  1961  7375454614.0  12561701694.0  7058360972.0  5983900493.0
# 2  1962  7823686765.0  13436827167.0  7953274452.0  6407225035.0
# 3  1963  8447136820.0  14445805381.0  8466044672.0          <NA>
# 4  1964  9249879079.0  16168044450.0  9677400985.0  7848288358.0
#
#           France         Germany        Greece      Iceland       Ireland  \
# 0  62225478001.0   84310950194.0  4335191696.0  252169712.0  1998550222.0
# 1  67461644222.0   96205728658.0  4961399303.0  257703244.6  2151772980.0
# 2  75607529810.0  105509000000.0  5213043168.0  289200704.4  2329372972.0
# 3  84759195106.0  111823000000.0  5895281432.0  345175036.1  2505073358.0
# 4  94007851047.0  122880000000.0  6669669850.0  440797869.3  2851091646.0
#
#            Italy   Luxembourg    Netherlands        Norway      Portugal  \
# ...

# %%
Europe_GDP.tail()
# Out:
#     Year         Austria         Belgium         Denmark         Finland  \
# 59  2019  444596000000.0  535866000000.0  346499000000.0  268515000000.0
# 60  2020  435049000000.0  526022000000.0  354763000000.0  271886000000.0
# 61  2021  479295000000.0  600904000000.0  405688000000.0  296470000000.0
# 62  2022  470942000000.0  583614000000.0  400167000000.0  281887000000.0
# 63  2023  516034000000.0  632217000000.0  404199000000.0  300187000000.0
#
#              France          Germany          Greece        Iceland  \
# 59  2728870000000.0  3889180000000.0  205253000000.0  24681343649.0
# 60  2647420000000.0  3887730000000.0  188480000000.0  21629953194.0
# 61  2959360000000.0  4278500000000.0  214668000000.0  25797870984.0
# 62  2779090000000.0  4082470000000.0  217581000000.0  28701830402.0
# 63  3030900000000.0  4456080000000.0  238206000000.0  31020032583.0
#
#            Ireland            Italy     Luxembourg      Netherlands  \
# ...

# %%
Europe_GDP.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year            64 non-null     Int64
#  1   Austria         64 non-null     Float64
#  2   Belgium         64 non-null     Float64
#  3   Denmark         64 non-null     Float64
#  4   Finland         63 non-null     Float64
#  5   France          64 non-null     Float64
#  6   Germany         64 non-null     Float64
#  7   Greece          63 non-null     Float64
#  8   Iceland         64 non-null     Float64
#  9   Ireland         64 non-null     Float64
#  10  Italy           64 non-null     Float64
#  11  Luxembourg      64 non-null     Float64
#  12  Netherlands     64 non-null     Float64
#  13  Norway          64 non-null     Float64
#  14  Portugal        64 non-null     Float64
#  15  Spain           64 non-null     Float64
#  16  Sweden          64 non-null     Float64
# ...

# %%
Europe_GDP.describe()
# Out:
#             Year              Austria              Belgium  \
# count       64.0                 64.0                 64.0
# mean      1991.5  197169664954.484375  242886731007.515625
# std    18.618987  165483770120.393219  197317654626.934448
# min       1960.0         6650133915.0        11810619368.0
# 25%      1975.75       42234783857.25       69754959500.25
# 50%       1991.5       182087000000.0       217616500000.0
# 75%      2007.25       383774750000.0       464482500000.0
# max       2023.0       516034000000.0       632217000000.0
#
#                    Denmark              Finland               France  \
# count                 64.0                 63.0                 64.0
# mean   161727049754.578125  127253627734.444443  1332030651534.15625
# std    131759471212.771713  101117025719.571625  1026789067921.05957
# min           6361166313.0         5279011362.0        62225478001.0
# 25%         43550520908.75        32674656546.0       369447250000.0
# ...

# %%
Europe_GDP.columns
# Out:
# Index(['Year', 'Austria', 'Belgium', 'Denmark', 'Finland', 'France', 'Germany',
#        'Greece', 'Iceland', 'Ireland', 'Italy', 'Luxembourg', 'Netherlands',
#        'Norway', 'Portugal', 'Spain', 'Sweden', 'Switzerland',
#        'United Kingdom'],
#       dtype='object')

# %%
Europe_GDP.loc[Europe_GDP.isna().any(axis="columns")]
# Out:
#    Year        Austria        Belgium        Denmark       Finland  \
# 3  1963   8447136820.0  14445805381.0   8466044672.0          <NA>
# 5  1965  10081145818.0  17597783297.0  10870670470.0  8679620317.0
#
#            France         Germany        Greece      Iceland       Ireland  \
# 3   84759195106.0  111823000000.0  5895281432.0  345175036.1  2505073358.0
# 5  101537000000.0  134283000000.0          <NA>  531569563.9  3035655794.0
#
#            Italy   Luxembourg    Netherlands        Norway      Portugal  \
# 3  59897871868.0  797902154.2  17168477020.0  6553269536.0  4084251593.0
# 5  70554398250.0  929477284.8  22688478855.0  8111945661.0  4901711248.0
#
#            Spain         Sweden    Switzerland  United Kingdom
# 3  19645746986.0  20371666154.0  14283872299.0   86561961812.0
# 5  25497831759.0  25000191834.0  16780226225.0  101825000000.0

# %%
Europe_GDP.nunique()
# Out:
# Year              64
# Austria           64
# Belgium           64
# Denmark           64
# Finland           63
# France            64
# Germany           64
# Greece            63
# Iceland           64
# Ireland           64
# Italy             64
# Luxembourg        64
# Netherlands       64
# Norway            64
# Portugal          64
# Spain             64
# Sweden            64
# Switzerland       64
# United Kingdom    64
# dtype: int64

# %%
Europe_GDP.isnull().sum()
# Out:
# Year              0
# Austria           0
# Belgium           0
# Denmark           0
# Finland           1
# France            0
# Germany           0
# Greece            1
# Iceland           0
# Ireland           0
# Italy             0
# Luxembourg        0
# Netherlands       0
# Norway            0
# Portugal          0
# Spain             0
# Sweden            0
# Switzerland       0
# United Kingdom    0
# dtype: int64

# %%
(Europe_GDP.isnull().sum()/(len(Europe_GDP)))*100
# Out:
# Year              0.0000
# Austria           0.0000
# Belgium           0.0000
# Denmark           0.0000
# Finland           1.5625
# France            0.0000
# Germany           0.0000
# Greece            1.5625
# Iceland           0.0000
# Ireland           0.0000
# Italy             0.0000
# Luxembourg        0.0000
# Netherlands       0.0000
# Norway            0.0000
# Portugal          0.0000
# Spain             0.0000
# Sweden            0.0000
# Switzerland       0.0000
# United Kingdom    0.0000
# dtype: float64

# %%
Europe_GDP.describe(include='all').T
# Out:
#                 count                  mean                   std  \
# Year             64.0                1991.5             18.618987
# Austria          64.0   197169664954.484375   165483770120.393219
# Belgium          64.0   242886731007.515625   197317654626.934448
# Denmark          64.0   161727049754.578125   131759471212.771713
# Finland          63.0   127253627734.444443   101117025719.571625
# France           64.0   1332030651534.15625   1026789067921.05957
# Germany          64.0    1857700932482.0625  1414251863858.767578
# Greece           63.0   123036825630.444443    99532801154.493134
# Iceland          64.0     8909102491.429688     8510868938.693439
# Ireland          64.0   123625162427.640625    148774123204.99408
# Italy            64.0   1055383789636.28125   808121713103.124146
# Luxembourg       64.0    25419948918.957813    27158870234.471432
# Netherlands      64.0   411682258424.546875   345449754011.762329
# ...

# %%
Europe_GDP.loc[Europe_GDP.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Year, Austria, Belgium, Denmark, Finland, France, Germany, Greece, Iceland, Ireland, Italy, Luxembourg, Netherlands, Norway, Portugal, Spain, Sweden, Switzerland, United Kingdom]
# Index: []

# %%
In [36]: Europe_GDP.to_csv("Europe_GDP cleansed.csv", index=False)

# %%
In [1]: import pandas as pd
   ...: import matplotlib.pyplot as plt
   ...:
   ...: data = pd.read_csv("Europe_GDP cleansed.csv").convert_dtypes()

# %%
In [2]: fig, ax = plt.subplots()
   ...: ax.scatter(data["Denmark"], data["Belgium"])
   ...: ax.set_title("Scatter Plot")
   ...: ax.set_xlabel("X-axis")
   ...: ax.set_ylabel("Y-axis")
   ...: fig.show()

# %%
plt.figure(figsize=(12, 7))

# Chaining methods properly
sns.heatmap(
    Europe_GDP.drop(['Finland', 'Iceland'], axis=1)  # Drop specified columns
    .select_dtypes(include=['number'])  # Keep only numeric columns
    .corr(),  # Compute the correlation matrix
    annot=True, vmin=-1, vmax=1  # Show annotations and set the range for correlation
)

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check column names first to ensure the column exists in the correlation matrix
print(numeric_data.columns)

# Drop 'Finland' and 'Iceland' columns from the original dataset, then compute correlations
corr_values = Europe_GDP.drop(['Finland', 'Iceland'], axis=1)  # Drop specified columns
numeric_data = corr_values.select_dtypes(include=['number'])  # Keep only numeric columns

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()

# If you're trying to drop a country like 'Iceland' from the correlation matrix,
# Make sure the country exists in the correlation matrix, and drop it correctly.
try:
    correlation_with_belgium = correlation_matrix['Belgium'].drop('Belgium')  # Drop self-correlation with Belgium
except KeyError:
    print("The column 'Belgium' is not found in the correlation matrix.")
    
# Plot the correlation of other countries with 'Belgium'
plt.figure(figsize=(10, 6))
correlation_with_belgium.sort_values(ascending=False).plot(kind='bar', color='skyblue')

# Adding labels and title
plt.title('Correlation with Belgium')
plt.xlabel('Countries')
plt.ylabel('Correlation Coefficient')
plt.xticks(rotation=45)
plt.show()
# Out:
# Index(['Year', 'Austria', 'Belgium', 'Denmark', 'France', 'Germany', 'Greece',
#        'Ireland', 'Italy', 'Luxembourg', 'Netherlands', 'Norway', 'Portugal',
#        'Spain', 'Sweden', 'Switzerland', 'United Kingdom'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check column names first to ensure the column exists in the correlation matrix
print(numeric_data.columns)

# Drop 'Finland' and 'Iceland' columns from the original dataset, then compute correlations
corr_values = Europe_GDP.drop(['Finland', 'Iceland'], axis=1)  # Drop specified columns
numeric_data = corr_values.select_dtypes(include=['number'])  # Keep only numeric columns

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()

# If you're trying to drop a country like 'Iceland' from the correlation matrix,
# Make sure the country exists in the correlation matrix, and drop it correctly.

# Plot a histogram of the correlations (excluding self-correlation)
plt.figure(figsize=(10, 6))
correlation_with_belgium.sort_values(ascending=False).plot(kind='hist', bins=10, color='skyblue', edgecolor='black')

# Adding labels and title
plt.title('Histogram of Correlations with Belgium')
plt.xlabel('Correlation Coefficient')
plt.ylabel('Frequency')
plt.show()
# Out:
# Index(['Year', 'Austria', 'Belgium', 'Denmark', 'France', 'Germany', 'Greece',
#        'Ireland', 'Italy', 'Luxembourg', 'Netherlands', 'Norway', 'Portugal',
#        'Spain', 'Sweden', 'Switzerland', 'United Kingdom'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Check column names first to ensure the column exists in the correlation matrix
# Drop 'Finland' and 'Iceland' columns from the original dataset, then compute correlations
corr_values = Europe_GDP.drop(['Finland', 'Iceland'], axis=1)  # Drop specified columns
numeric_data = corr_values.select_dtypes(include=['number'])  # Keep only numeric columns

# Calculate correlation matrix
correlation_matrix = numeric_data.corr()
# Plot a line plot of the correlations (excluding self-correlation)
plt.figure(figsize=(10, 6))
correlation_with_belgium.sort_values(ascending=False).plot(kind='line', color='skyblue', linewidth=2)

# Adding labels and title
plt.title('Line Plot of Correlations with Belgium')
plt.xlabel('Country')
plt.ylabel('Correlation Coefficient')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
import seaborn as sns
tips = sns.load_dataset("tips")
sns.scatterplot(x="total_bill", y="tip", data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import seaborn as sns
fmri = sns.load_dataset("fmri")
sns.lineplot(x="timepoint", y="signal", data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
