# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("Advertising.csv")

# %%
data.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
data.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
data.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
# Splitting variables
X = data[['TV']]  # Independent variable (TV advertising budget)
y = data[['sales']]

# %%
# Splitting the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Creating and training the Linear Regression model using sklearn
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Intercept:", model.intercept_)
print("Coefficients:", model.coef_)
# Out:
# Intercept: 2.979067338122629
# Coefficients: [0.04472952 0.18919505 0.00276111]

# %%
# Making predictions
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mse, r2
# Out:
# (3.1740973539761033, 0.899438024100912)

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred_test, color='blue')
plt.xlabel("Actual Sales")
plt.ylabel("Predicted Sales")
plt.title("Actual vs Predicted Sales")
plt.show()

# %%
plt.title("Sales Distribution Plot")
sns.histplot(y, kde=True)
plt.show()

# %%
# Splitting variables
X = data.iloc[:, :1]  # independent variable
y = data.iloc[:, 1:]  # dependent variable

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Making predictions
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train

# %%
# Training Set Visualization
plt.figure(figsize=(8, 6))
plt.scatter(X_train.values.flatten(), y_train.values.flatten(), color='lightcoral')  # Fix shape issue
plt.plot(X_train.values.flatten(), y_pred_train.flatten(), color='firebrick')  # Fix shape issue
plt.title('TV Advertising Budget vs Sales (Training Set)')
plt.xlabel('TV Advertising Budget')
plt.ylabel('Sales')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title='Sales/TV', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(X_test.values.flatten(), y_test.values.flatten(), color='lightcoral')  # Fix shape issue
plt.plot(X_train.values.flatten(), y_pred_train.flatten(), color='firebrick')  # Fix shape issue
plt.title('TV Advertising Budget vs Sales (Test Set)')
plt.xlabel('TV Advertising Budget')
plt.ylabel('Sales')
plt.legend(['X_train/Pred(y_test)', 'X_test/y_test'], title='Sales/TV', loc='best', facecolor='white')
plt.box(False)
plt.show()
